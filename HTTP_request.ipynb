# %% [markdown]
# WEB REQUESTS

# %%
import requests

response = requests.get('https://www.platzi.com')
response.encoding=('utf-8')
print(dir(response))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %% [markdown]
# Status code:
# 1XX: información
# 2XX: éxito
# 3XX: redireccionamiento
# 4XX: error del cliente (usted cometió un error)
# 5XX: error del servidor (se cometió un error en este)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.headers)
# Out:
# {'Date': 'Wed, 08 Jun 2022 15:29:33 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'CF-Ray': '7182a9e6fe90e5af-BOG', 'Access-Control-Allow-Origin': '*', 'Age': '5334', 'Cache-Control': 'no-store', 'Expires': 'Thu, 08 Jun 2023 15:29:33 GMT', 'Set-Cookie': 'pac-hRur47GmYKfmFy=B; path=/; Expires=Wed Jun 08 2022 00:00:00 GMT+0000 (Coordinated Universal Time);', 'Strict-Transport-Security': 'max-age=15552000; includeSubDomains; preload', 'Vary': 'Accept-Encoding', 'CF-Cache-Status': 'HIT', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': 'X-Requested-With,content-type,X-CSRFToken', 'Access-Control-Allow-Methods': 'GET, POST', 'Expect-CT': 'max-age=0', 'Referrer-Policy': 'no-referrer', 'X-Content-Type-Options': 'nosniff', 'X-DNS-Prefetch-Control': 'off', 'X-Download-Options': 'noopen', 'X-Frame-Options': 'SAMEORIGIN', 'X-Permitted-Cross-Domain-Policies': 'none', 'X-XSS-Protection': '0', 'Server': 'clo
# ...

# %%
print(response.headers['Date'])
# Out:
# Wed, 08 Jun 2022 15:29:33 GMT

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang=es>
# <head>
# <meta charset="UTF-8">
# <title>Platzi: ‎Cursos Online Profesionales de Tecnología</title>
# <meta name="viewport" content="width=device-width, initial-scale=1" />
# <meta name="referrer" content="no-referrer-when-downgrade">
# <meta name="description" content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!">
# <meta name="theme-color" content="#15210B" />
# <meta property="fb:app_id" content="263680607075199" />
# <meta property="fb:admins" content="1030603473" />
# <meta property="og:description" content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!" />
# <meta property="og:title" content="Platzi: ‎Cursos Online Profesionales de Tecnología" />
# <meta property="og:type" content="website" />
# ...

# %% [markdown]
# Extracting information from HTML
# using beautiful soup and requests

# %%
import bs4

soup = bs4.BeautifulSoup(response.text, 'html.parser')

print(soup.select('meta[name="description"]')[0]['content'])
# Out:
# Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!

# %% [markdown]
# links on the platzys web page
#
# With beautiful soup we have to know the structure of the page

# %%
courses_link = soup.select('.Categories-category-item')
schools = [school['href'] for school in courses_link]

for school in schools:
    print(school)
# Out:
# /categorias/negocios/
# /categorias/startups/
# /categorias/marketing/
# /categorias/crecimiento-profesional/
# /categorias/diseno/
# /categorias/contenido-digital/
# /categorias/desarrollo/
# /categorias/english/
